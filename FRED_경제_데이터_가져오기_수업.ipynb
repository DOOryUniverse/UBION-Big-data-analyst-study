# %% [markdown]
# <a href="https://colab.research.google.com/github/DOOryUniverse/UBION-Big-data-analyst-study/blob/main/FRED_%EA%B2%BD%EC%A0%9C_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EA%B0%80%EC%A0%B8%EC%98%A4%EA%B8%B0_%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
S = pd.Series([1,2,3])
S.describe()
# Out:
# count    3.0
# mean     2.0
# std      1.0
# min      1.0
# 25%      1.5
# 50%      2.0
# 75%      2.5
# max      3.0
# dtype: float64

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2022, 1, 27)
gdp = web.DataReader('GDP', 'fred', start, end)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2010-01-01 to 2021-10-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDP     48 non-null     float64
# dtypes: float64(1)
# memory usage: 768.0 bytes

# %%
gdp.describe()
# Out:
#                 GDP
# count     48.000000
# mean   18622.022042
# std     2438.286708
# min    14764.611000
# 25%    16576.884000
# 50%    18378.692500
# 75%    20697.657750
# max    23992.355000

# %%
gdp
# Out:
#                   GDP
# DATE
# 2010-01-01  14764.611
# 2010-04-01  14980.193
# 2010-07-01  15141.605
# 2010-10-01  15309.471
# 2011-01-01  15351.444
# 2011-04-01  15557.535
# 2011-07-01  15647.681
# 2011-10-01  15842.267
# 2012-01-01  16068.824
# 2012-04-01  16207.130
# 2012-07-01  16319.540
# 2012-10-01  16420.386
# 2013-01-01  16629.050
# 2013-04-01  16699.551
# 2013-07-01  16911.068
# 2013-10-01  17133.114
# 2014-01-01  17144.281
# 2014-04-01  17462.703
# 2014-07-01  17743.227
# 2014-10-01  17852.540
# 2015-01-01  17991.348
# 2015-04-01  18193.707
# 2015-07-01  18306.960
# 2015-10-01  18332.079
# 2016-01-01  18425.306
# 2016-04-01  18611.617
# 2016-07-01  18775.459
# 2016-10-01  18968.041
# 2017-01-01  19153.912
# 2017-04-01  19322.920
# 2017-07-01  19558.693
# 2017-10-01  19882.965
# 2018-01-01  20143.716
# 2018-04-01  20492.492
# 2018-07-01  20659.102
# 2018-10-01  20813.325
# 2019-01-01  21001.591
# 2019-04-01  21289.268
# 2019-07-01  21505.012
# 2019-10-01  21694.458
# ...

# %%
pip install fredapi

# %%
pip install full-fred
# Out:
# ...
#      |████████████████████████████████| 47 kB 4.2 MB/s
# ...

# %%
from fredapi import Fred
fred = Fred(api_key='8f530912a1e3fc8ac2408d64a8753476')
data = fred.get_series('GDP')

# %%
data=fred.get_series_first_release('GDP')
data.tail()
# Out:
# date
# 2020-10-01    21479.529
# 2021-01-01    22048.894
# 2021-04-01    22722.581
# 2021-07-01    23173.496
# 2021-10-01    23992.355
# Name: value, dtype: object

# %%
fred.get_series_as_of_date('GDP', '09/2/2022')
# Out:
#      realtime_start       date      value
# 0        1992-12-22 1946-01-01      199.7
# 1        1996-01-19 1946-01-01        NaT
# 2        1997-05-07 1946-01-01      210.4
# 3        1999-10-28 1946-01-01        NaT
# 4        1992-12-22 1946-04-01      207.7
# ...             ...        ...        ...
# 3064     2021-09-30 2021-04-01  22740.959
# 3065     2021-10-28 2021-07-01  23173.496
# 3066     2021-11-24 2021-07-01  23187.042
# 3067     2021-12-22 2021-07-01  23202.344
# 3068     2022-01-27 2021-10-01  23992.355
#
# [3069 rows x 3 columns]

# %%
from fredapi import Fred
fred = Fred(api_key='8f530912a1e3fc8ac2408d64a8753476')
data = fred.get_series('DGS10')

# %%
data = fred.get_series_first_release('DGS10')
data.tail(50)
# Out:
# date
# 2021-12-01    1.43
# 2021-12-02    1.44
# 2021-12-03    1.35
# 2021-12-06    1.43
# 2021-12-07    1.48
# 2021-12-08    1.52
# 2021-12-09    1.49
# 2021-12-10    1.48
# 2021-12-13    1.42
# 2021-12-14    1.44
# 2021-12-15    1.47
# 2021-12-16    1.44
# 2021-12-17    1.41
# 2021-12-20    1.43
# 2021-12-21    1.48
# 2021-12-22    1.46
# 2021-12-23     1.5
# 2021-12-24     NaT
# 2021-12-27    1.48
# 2021-12-28    1.49
# 2021-12-29    1.55
# 2021-12-30    1.52
# 2021-12-31    1.52
# 2022-01-03    1.63
# 2022-01-04    1.66
# 2022-01-05    1.71
# 2022-01-06    1.73
# 2022-01-07    1.76
# 2022-01-10    1.78
# 2022-01-11    1.75
# 2022-01-12    1.74
# 2022-01-13     1.7
# 2022-01-14    1.78
# 2022-01-17     NaT
# 2022-01-18    1.87
# 2022-01-19    1.83
# 2022-01-20    1.83
# 2022-01-21    1.75
# 2022-01-24    1.75
# 2022-01-25    1.78
# 2022-01-26    1.85
# 2022-01-27    1.81
# 2022-01-28    1.78
# 2022-01-31    1.79
# 2022-02-01    1.81
# 2022-02-02    1.78
# 2022-02-03    1.82
# ...

# %%
# !pip install -U finance-datareader

# %%
import FinanceDataReader as fdr
fdr.__version__
# Out:
# '0.9.31'

# %%
import FinanceDataReader as fdr
# 삼성전자, 2021년
df = fdr.DataReader('005930', "2021")
import FinanceDataReader as fdr
df. head()
# Out:
#              Open   High    Low  Close    Volume    Change
# Date
# 2021-01-04  81000  84400  80200  83000  38655276  0.024691
# 2021-01-05  81600  83900  81600  83900  35335669  0.010843
# 2021-01-06  83300  84500  82100  82200  42089013 -0.020262
# 2021-01-07  82800  84200  82700  82900  32644642  0.008516
# 2021-01-08  83300  90000  83000  88800  59013307  0.071170

# %%
import FinanceDataReader as fdr
df= fdr.DataReader("005930", "2021")
df['Close'].plot()

# %%
import FinanceDataReader as fdr
# 삼성전자, 2018년 부터 2021년까지
df = fdr.DataReader('005930', "2018", "2021")
import FinanceDataReader as fdr
df. head()
# Out:
#              Open   High    Low  Close  Volume    Change
# Date
# 2018-01-02  51380  51400  50780  51020  169485  0.001177
# 2018-01-03  52540  52560  51420  51620  200270  0.011760
# 2018-01-04  52120  52180  50640  51080  233909 -0.010461
# 2018-01-05  51300  52120  51200  52120  189623  0.020360
# 2018-01-08  52400  52520  51500  52020  167673 -0.001919

# %%
import FinanceDataReader as fdr
import pandas as pd
df = fdr.DataReader('005930', "2018", "2021")
df.to_csv('se.csv', encoding='utf-8-sig')

# %%
import FinanceDataReader as fdr
import pandas as pd
df = fdr.DataReader('005930', "2018", "2021")
# df.to_csv('se.csv', encoding='utf-8-sig')
df.to_excel('se.xlsx')

# %%
import FinanceDataReader as fdr
df= fdr.DataReader("005930", "2018", "2022")
df['Close'].plot()

# %%
import FinanceDataReader as fdr
df= fdr.DataReader("005930", "2018-01-01", "2022-02-09")
df['Close'].plot()

# %%
#엔비디아 주가(NVDA)
df = fdr.DataReader('NVDA', "2018")
df.tail()
# Out:
#              Close    Open    High     Low      Volume  Change
# Date
# 2022-02-03  239.48  244.58  250.77  237.80  39410000.0 -0.0513
# 2022-02-04  243.19  239.72  246.35  236.32  35480000.0  0.0155
# 2022-02-07  247.28  243.72  251.82  242.02  37400000.0  0.0168
# 2022-02-08  251.08  243.59  252.30  239.80  41040000.0  0.0154
# 2022-02-09  267.05  256.22  267.25  253.53  51990000.0  0.0636

# %%
#KOSPI(KS11)
df = fdr.DataReader('KS11', "2015")
df['Close'].plot()

# %%
#다우지수(DJI)
df = fdr.DataReader('DJI', "2015")
df['Close'].plot()

# %%
# 환율 시각화
import FinanceDataReader as fdr
#원달러환율(USD/KRW)
df = fdr.DataReader('USD/KRW', "1995")
df['Close'].plot()

# %%
#암호화폐가격 비트코인(빗썸)
import FinanceDataReader as fdr
df = fdr.DataReader('BTC/KRW', "2016")
df.head()
df['Close'].plot()

# %%
import FinanceDataReader as fdr

df = fdr.DataReader('005930', '2021-01-01', '2021-02-15')
fdr.chart.plot(df)
# Out:
#   <div class="bk-root" id="bc004f23-7f04-437a-be96-27ce09eb1a2c" data-root-id="1153"></div>

# %%
fdr.chart.plot(df, title='삼성전자(005930)')
# Out:
#   <div class="bk-root" id="ee9171ed-f41c-4c5f-8a2d-bb7771003716" data-root-id="1497"></div>

# %%
#  야후 파이낸스 주가데이터 가져오기
# !pip install yfinance -user
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -u

# %%
import yfinance as yf

# %%
pip show yfinace
# Out:
# WARNING: Package(s) not found: yfinace

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-70-2cece484f83d> in <module>()
#       1 from pandas_datareader import data as pdr
# ----> 2 import yfinance as yf
#       3 yf.pdr_override()
#
# ModuleNotFoundError: No module named 'yfinance'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
